# %%
# Gemini API quickstart
import google.generativeai as genai

genai.configure(api_key="AIzaSyCfWXVgeNxl3DrtkqqnIK4JegZHqrf3WZg")
model = genai.GenerativeModel("gemini-1.5-flash")
response = model.generate_content("Where is France?")

# Assuming response has multiple parts and each part contains a 'text' attribute
texts = [part.text for part in response.parts]  # Adjust attribute access according to the actual structure
print(" ".join(texts))
# Out:
# France is located in Western Europe.

# %%
# Fine-tuning tutorial
import google.generativeai as genai

genai.configure(api_key="AIzaSyCfWXVgeNxl3DrtkqqnIK4JegZHqrf3WZg")
model = genai.GenerativeModel(model_name="tunedModels/setting31-pyqjjzkvngvn")
response = model.generate_content("Where is France?")

# Assuming response has multiple parts and each part contains a 'text' attribute
texts = [part.text for part in response.parts]  # Adjust attribute access according to the actual structure
print(" ".join(texts))
# Out:
# France is located in Western Europe.
#
# * **Latitude:** 42.5° N to 51.1° N
# * **Longitude:** 2.5° W to 9.5° E
# * **Bordering countries:** Belgium, Luxembourg, Germany, Switzerland, Italy, Monaco, Spain, Andorra, and the Netherlands
#
# France also includes several overseas territories and dependencies located in other parts of the world.

# %%
# Original model result for NewSamples
import pandas as pd
import google.generativeai as genai
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

def initialize_genai_model(api_key, model_name="gemini-1.5-flash"):
    """Initialize and return the generative model."""
    genai.configure(api_key=api_key)
    model = genai.GenerativeModel(model_name)
    return model

def process_medical_queries(model, test_data):
    """Process medical queries by adding instructions and obtaining model responses."""
    instruction = "Suppose that you are a medical diagnosis assistant, skilled in recognizing diseases and prescribing treatments. If a patient has the following condition, give me the most probable diagnosis and the related probability and urgency and rationale for the diagnosis besides suitable treatments. Start your response with Diagnosis:"
    results = []
    stop_words = set(stopwords.words('english'))

    for index, row in test_data.iterrows():
        query = f"{instruction} {row['Patient Conditions']}"
        response = model.generate_content(query)
        texts = [part.text for part in response.parts]
        first_diagnosis = " ".join(texts).split('.')[0]

        correct_keywords = set(row['Correct Diagnosis'].lower().split()) - stop_words
        output_keywords = set(first_diagnosis.lower().split()) - stop_words
        correct_count = len(correct_keywords & output_keywords)
        percentage_correct = (correct_count / len(correct_keywords)) * 100 if correct_keywords else 0
        is_correct = percentage_correct >= 50

        results.append((index, row['Correct Diagnosis'], first_diagnosis, is_correct))
        print(f"Processed {index + 1}/{len(test_data)} cases.")

    return results

def calculate_accuracy(results):
    """Calculate the accuracy of the diagnosis predictions."""
    total_cases = len(results)
    correct_cases = sum(1 for _, _, _, is_correct in results if is_correct)
    accuracy = (correct_cases / total_cases) * 100
    return accuracy

def read_test_data(file_path):
    """Read test data from an Excel file."""
    return pd.read_excel(file_path)

# API Key and Model Name
api_key = "AIzaSyCfWXVgeNxl3DrtkqqnIK4JegZHqrf3WZg"
model_name = "gemini-1.5-flash"

# Initialize the model
model = initialize_genai_model(api_key, model_name)

# Read Test Data from Excel
file_path = 'Test_Data.xlsx'
test_data = read_test_data(file_path)

# Process the test data with the model
diagnoses_results = process_medical_queries(model, test_data)

# Print results
for index, correct_diagnosis, first_diagnosis, is_correct in diagnoses_results:
    print(f"Case {index + 1}:")
    print(f"Correct Diagnosis: {correct_diagnosis}")
    print(f"LLM Output Diagnosis: {first_diagnosis}")
    print(f"Is the diagnosis correct? {'Yes' if is_correct else 'No'}\n")

# Calculate and print the accuracy
accuracy = calculate_accuracy(diagnoses_results)
print(f"Accuracy of the diagnoses: {accuracy:.2f}%")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/zhangxijing/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Processed 1/20 cases.
# Processed 2/20 cases.
# Processed 3/20 cases.
# Processed 4/20 cases.
# Processed 5/20 cases.
# Processed 6/20 cases.
# Processed 7/20 cases.
# Processed 8/20 cases.
# Processed 9/20 cases.
# Processed 10/20 cases.
# Processed 11/20 cases.
# Processed 12/20 cases.
# Processed 13/20 cases.
# Processed 14/20 cases.
# Processed 15/20 cases.
# Processed 16/20 cases.
# Processed 17/20 cases.
# Processed 18/20 cases.
# Processed 19/20 cases.
# Processed 20/20 cases.
# Case 1:
# Correct Diagnosis: Cerebral Malaria
# LLM Output Diagnosis: **Diagnosis:**  Neurological deterioration secondary to suspected Neurocysticercosis (NCC)
#
# **Probability:** Moderate to High (60-80%)
# Is the diagnosis correct? No
#
# Case 2:
# Correct Diagnosis: Sepsis
# LLM Output Diagnosis: **Diagnosis:** Esophageal Carcinoma with Sepsis and Complicated Hospital Course
#
# **Probability:** High (Given the clinical presentation, radiological findings, and biopsy results, esophageal carcinoma is the most likely diagnosis
# Is the diagnosis correct? Yes
#
# Case 3:
# Correct Diagnosis: type I necrotizing fasciitis, sepsis
# LLM Output Diagnosis: **Diagnosis:**  Retroperitoneal abscess secondary to perforated appendicitis
#
# **Probability:** High (≥90%)
# Is the diagnosis correct? No
#
# Case 4:
# Correct Diagnosis: Septic arthritis, impending avascular necrosis, brucella infection
# LLM Output Diagnosis: **Diagnosis:** Septic arthritis of the right hip
#
# **Probability:** High (Given the clinical presentation, laboratory findings, and imaging results, septic arthritis is the most likely diagnosis)
# Is the diagnosis correct? No
#
# Case 5:
# Correct Diagnosis: sepsis, cellulitis, aortitis, tricuspid insufficiency, septic vegetation, endocarditis
# LLM Output Diagnosis: **Diagnosis:**  Septic shock secondary to necrotizing fasciitis (right upper leg) with possible concurrent disseminated intravascular coagulation (DIC)
# Is the diagnosis correct? No
#
# Case 6:
# Correct Diagnosis: salmonella minor infection, sepsis, mycotic aortic aneurysm, aortitis, abscess, drug allergy
# LLM Output Diagnosis: **Diagnosis:** Salmonella-induced mycotic aneurysm of the aorta
#
# **Probability:** High (Given the positive blood and abscess cultures of *Salmonella Choleraesuis*, the imaging findings consistent with infective aortitis, paraaortic abscess, and mycotic aneurysm, and the clinical presentation including fever, chills, abdominal pain, and skin rash despite initial antibiotic treatment)
# Is the diagnosis correct? No
#
# Case 7:
# Correct Diagnosis:  indigestion
# LLM Output Diagnosis: **Diagnosis:** Vasovagal Syncope
#
# **Probability:** High (80-90%)
#
# **Urgency:** Low to Moderate
#
# **Rationale:**
#
# The patient's presentation strongly suggests vasovagal syncope
# Is the diagnosis correct? No
#
# Case 8:
# Correct Diagnosis: urosepsis
# LLM Output Diagnosis: **Diagnosis:** Fournier's Gangrene
#
# **Probability:** High (given the rapid deterioration, soft tissue gas on CT, and positive culture for *Eggerthella lenta*)
#
# **Urgency:** Extremely Urgent (This is a life-threatening condition requiring immediate intervention
# Is the diagnosis correct? No
#
# Case 9:
# Correct Diagnosis: Septic arthritis
# LLM Output Diagnosis: **Diagnosis:** Disseminated Methicillin-Sensitive Staphylococcus aureus (MSSA) infection with septic arthritis, epididymo-orchitis, and perineal abscess
# Is the diagnosis correct? Yes
#
# Case 10:
# Correct Diagnosis: Hemophagocytic Lymphohistiocytosis (HLH)
#
# LLM Output Diagnosis: **Diagnosis:** Hemophagocytic Lymphohistiocytosis (HLH) secondary to Rickettsial infection
#
# **Probability:** High
# Is the diagnosis correct? Yes
#
# Case 11:
# Correct Diagnosis: periorbital cellulitis
# LLM Output Diagnosis: **Diagnosis:** Orbital Emphysema
#
# **Probability:** High (near certainty given the presented clinical picture and CT findings)
# Is the diagnosis correct? No
#
# Case 12:
# Correct Diagnosis: cardio-embolism, ischemic stroke
# LLM Output Diagnosis: **Diagnosis:** Vertebrobasilar Stroke secondary to Vertebral Artery Hypoplasia and Persistent Trigeminal Artery (PTA)
#
# **Probability:** High
# Is the diagnosis correct? No
#
# Case 13:
# Correct Diagnosis: UC re-activation
# LLM Output Diagnosis: **Diagnosis:** ANCA-associated vasculitis (Microscopic Polyangiitis) with superimposed ulcerative colitis
#
# **Probability:** High
# Is the diagnosis correct? No
#
# Case 14:
# Correct Diagnosis: viral myocarditis, viral sepsis
# LLM Output Diagnosis: **Diagnosis:** Myocarditis (viral, likely influenza A)
#
# **Probability:** High ( >80%)
# Is the diagnosis correct? No
#
# Case 15:
# Correct Diagnosis:  Pseudomonas aeruginosa diarrhea
# LLM Output Diagnosis: **Diagnosis:**  Pseudomonas aeruginosa sepsis secondary to abdominal compartment syndrome and complicated by myxedema coma
# Is the diagnosis correct? Yes
#
# Case 16:
# Correct Diagnosis: Intrabullous hemorrhage
# LLM Output Diagnosis: **Diagnosis:** Intrabullous Hemorrhage
#
# **Probability:** High (given the imaging findings and clinical course)
#
# **Urgency:** High (due to the presence of significant haemoptysis and chest pain)
#
# **Rationale:**
#
# The patient presented with several concerning symptoms:  sudden onset chest pain radiating to the neck, arms, and back; productive cough with blood-tinged sputum;  wheezing; pleuritic chest pain; progressive shortness of breath; and night sweats
# Is the diagnosis correct? Yes
#
# Case 17:
# Correct Diagnosis: sexual disorder secondary to therapy
# LLM Output Diagnosis: **Diagnosis:** Sexual arousal disorder secondary to galcanezumab treatment
# Is the diagnosis correct? Yes
#
# Case 18:
# Correct Diagnosis: unprovoked superficial thrombophlebitis
# LLM Output Diagnosis: **Diagnosis:** Trousseau Syndrome (Migratory Thrombophlebitis) secondary to malignancy
# Is the diagnosis correct? No
#
# Case 19:
# Correct Diagnosis: NOH
# LLM Output Diagnosis: **Diagnosis:** Neurocardiogenic Syncope (NCS) / Neurally Mediated Syncope (NMS) - also known as vasovagal syncope or reflex syncope
# Is the diagnosis correct? No
#
# Case 20:
# Correct Diagnosis: Carotid Sinus Hypersensitivity (CSS):
#
# LLM Output Diagnosis: **Diagnosis:** Carotid Sinus Hypersensitivity (Carotid Sinus Syndrome - CSS)
#
# **Probability:** High
# Is the diagnosis correct? Yes
#
# Accuracy of the diagnoses: 35.00%

# %%
# Original model result for FineTunedSample
import pandas as pd
import google.generativeai as genai
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

def initialize_genai_model(api_key, model_name="gemini-1.5-flash"):
    """Initialize and return the generative model."""
    genai.configure(api_key=api_key)
    model = genai.GenerativeModel(model_name)
    return model

def process_medical_queries(model, test_data):
    """Process medical queries by adding instructions and obtaining model responses."""
    instruction = "Suppose that you are a medical diagnosis assistant, skilled in recognizing diseases and prescribing treatments. If a patient has the following condition, give me the most probable diagnosis and the related probability and urgency and rationale for the diagnosis besides suitable treatments. Start your response with Diagnosis:"
    results = []
    stop_words = set(stopwords.words('english'))

    for index, row in test_data.iterrows():
        query = f"{instruction} {row['Patient Conditions']}"
        response = model.generate_content(query)
        texts = [part.text for part in response.parts]
        first_diagnosis = " ".join(texts).split('.')[0]

        correct_keywords = set(row['Correct Diagnosis'].lower().split()) - stop_words
        output_keywords = set(first_diagnosis.lower().split()) - stop_words
        correct_count = len(correct_keywords & output_keywords)
        percentage_correct = (correct_count / len(correct_keywords)) * 100 if correct_keywords else 0
        is_correct = percentage_correct >= 50

        results.append((index, row['Correct Diagnosis'], first_diagnosis, is_correct))
        print(f"Processed {index + 1}/{len(test_data)} cases.")

    return results

def calculate_accuracy(results):
    """Calculate the accuracy of the diagnosis predictions."""
    total_cases = len(results)
    correct_cases = sum(1 for _, _, _, is_correct in results if is_correct)
    accuracy = (correct_cases / total_cases) * 100
    return accuracy

def read_test_data(file_path, sheet_name=None):
    """Read test data from an Excel file, optionally specifying a sheet."""
    return pd.read_excel(file_path, sheet_name=sheet_name)

# API Key and Model Name
api_key = "AIzaSyCfWXVgeNxl3DrtkqqnIK4JegZHqrf3WZg"
model_name = "gemini-1.5-flash"

# Initialize the model
model = initialize_genai_model(api_key, model_name)

# Read Test Data from Excel
file_path = 'Test_Data.xlsx'
sheet_name = 'FineTunedSamples'  # Specify the sheet name here
test_data = read_test_data(file_path, sheet_name)

# Process the test data with the model
diagnoses_results = process_medical_queries(model, test_data)

# Print results
for index, correct_diagnosis, first_diagnosis, is_correct in diagnoses_results:
    print(f"Case {index + 1}:")
    print(f"Correct Diagnosis: {correct_diagnosis}")
    print(f"LLM Output Diagnosis: {first_diagnosis}")
    print(f"Is the diagnosis correct? {'Yes' if is_correct else 'No'}\n")

# Calculate and print the accuracy
accuracy = calculate_accuracy(diagnoses_results)
print(f"Accuracy of the diagnoses: {accuracy:.2f}%")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/zhangxijing/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Processed 1/20 cases.
# Processed 2/20 cases.
# Processed 3/20 cases.
# Processed 4/20 cases.
# Processed 5/20 cases.
# Processed 6/20 cases.
# Processed 7/20 cases.
# Processed 8/20 cases.
# Processed 9/20 cases.
# Processed 10/20 cases.
# Processed 11/20 cases.
# Processed 12/20 cases.
# Processed 13/20 cases.
# Processed 14/20 cases.
# Processed 15/20 cases.
# Processed 16/20 cases.
# Processed 17/20 cases.
# Processed 18/20 cases.
# Processed 19/20 cases.
# Processed 20/20 cases.
# Case 1:
# Correct Diagnosis: Pertussis
# LLM Output Diagnosis: **Diagnosis:** Acute Bronchitis
#
# **Probability:** High (80-90%)
#
# **Urgency:** Low to Moderate
# Is the diagnosis correct? No
#
# Case 2:
# Correct Diagnosis: COPD
# LLM Output Diagnosis: **Diagnosis:** Chronic Obstructive Pulmonary Disease (COPD) with possible underlying Bronchiectasis
# Is the diagnosis correct? No
#
# Case 3:
# Correct Diagnosis: Community-Acquired Pneumonia (CAP)
# LLM Output Diagnosis: **Diagnosis:** Community-Acquired Pneumonia (CAP)
#
# **Probability:** High (80-90%)  This is a strong probability given the classic presentation of CAP in an elderly, immunocompromised (due to age and smoking history) patient
# Is the diagnosis correct? Yes
#
# Case 4:
# Correct Diagnosis: Acute bacterial Prostatitis
# LLM Output Diagnosis: **Diagnosis:** Acute bacterial prostatitis
#
# **Probability:** High (70-80%)
# Is the diagnosis correct? Yes
#
# Case 5:
# Correct Diagnosis: Hairy cell leukemia variant
# LLM Output Diagnosis: **Diagnosis:** Hairy Cell Leukemia (HCL)
#
# **Probability:**  Very High
# Is the diagnosis correct? Yes
#
# Case 6:
# Correct Diagnosis: bacterial cystitis, dysbiosis
# LLM Output Diagnosis: **Diagnosis:**  Urethritis (most probable), possibly caused by a sexually transmitted infection (STI), specifically *Chlamydia trachomatis* or *Neisseria gonorrhoeae*
# Is the diagnosis correct? No
#
# Case 7:
# Correct Diagnosis: fatty liver disease
# LLM Output Diagnosis: **Diagnosis:** Cholelithiasis (Gallstones)
#
# **Probability:** High (70-80%)
#
# **Urgency:** Low to Moderate
#
# **Rationale:**
#
# The patient presents with several key indicators suggestive of cholelithiasis:
#
# * **Right upper quadrant (RUQ) abdominal pain:** This is a classic symptom of gallstones, often described as mild to moderate and radiating
# Is the diagnosis correct? No
#
# Case 8:
# Correct Diagnosis: urosepsis
# LLM Output Diagnosis: **Diagnosis:**  Urosepsis secondary to right ureteral stone with subsequent iliopsoas abscess
#
# **Probability:** High (given the presented clinical picture, lab results, imaging findings, and response to treatment)
# Is the diagnosis correct? Yes
#
# Case 9:
# Correct Diagnosis: Septick shock
# LLM Output Diagnosis: **Diagnosis:** Necrotizing fasciitis caused by *Vibrio metschnikovii*
#
# **Probability:** High
# Is the diagnosis correct? No
#
# Case 10:
# Correct Diagnosis: gastroenteritis
# LLM Output Diagnosis: Diagnosis: Acute Cholecystitis
#
# Probability:  High (70-80%)
#
# Urgency: High (Requires prompt evaluation and intervention)
#
# Rationale:
#
# The patient presents with classic symptoms suggestive of acute cholecystitis:
#
# * **Colicky abdominal pain:** This is characteristic of gallstone obstruction of the cystic duct
# Is the diagnosis correct? No
#
# Case 11:
# Correct Diagnosis: Septick shock
# LLM Output Diagnosis: **Diagnosis:** Septic shock secondary to Streptococcus pneumoniae infection complicated by disseminated intravascular coagulation (DIC) and acute renal failure, in the context of pre-existing autoimmune lymphoproliferative syndrome (ALPS) and prior splenectomy
# Is the diagnosis correct? Yes
#
# Case 12:
# Correct Diagnosis: COVID-19 associated stroke
# LLM Output Diagnosis: **Diagnosis:** Acute Posterior Circulation Stroke (AOP Stroke) secondary to COVID-19 infection
# Is the diagnosis correct? Yes
#
# Case 13:
# Correct Diagnosis: sexual disorder secondary to therapy
# LLM Output Diagnosis: **Diagnosis:**  Galcanezumab-induced sexual dysfunction (most probable), with secondary diagnosis of chronic migraine (refractory to Erenumab)
# Is the diagnosis correct? Yes
#
# Case 14:
# Correct Diagnosis: Lyme carditis
# LLM Output Diagnosis: Diagnosis: **Lyme Carditis**
#
# **Probability:** High (Given the clinical presentation, recent insect bite, and evolving heart block)
# Is the diagnosis correct? No
#
# Case 15:
# Correct Diagnosis: Metformin side effects
# LLM Output Diagnosis: **Diagnosis:** Severe Acute Kidney Injury (AKI) secondary to prerenal azotemia, likely precipitated by hypoglycemia
# Is the diagnosis correct? No
#
# Case 16:
# Correct Diagnosis: AIS
# LLM Output Diagnosis: **Diagnosis:** Cerebellar stroke (ischemic infarcts in bilateral cerebellar hemispheres, superior vermis, and PCA distribution) secondary to a likely cardioembolic source (Patent Foramen Ovale)
# Is the diagnosis correct? No
#
# Case 17:
# Correct Diagnosis: Galcanezumab-induced sexual dysfunction
# LLM Output Diagnosis: **Diagnosis:**  Loss of libido secondary to CGRP-inhibitor therapy (Galcanezumab)
# Is the diagnosis correct? No
#
# Case 18:
# Correct Diagnosis: infective pharyngitis
# LLM Output Diagnosis: **Diagnosis:** Acute Pharyngitis (likely viral)
#
# **Probability:** High (80-90%)
#
# **Urgency:** Low to Moderate
#
# **Rationale:**
#
# The patient presents with a classic picture of pharyngitis: fever, pharyngeal pain (throat pain), and redness and swelling of the pharynx
# Is the diagnosis correct? Yes
#
# Case 19:
# Correct Diagnosis: sexual disorder secondary to therapy
# LLM Output Diagnosis: **Diagnosis:** Sexual arousal disorder secondary to Galcanezumab treatment
# Is the diagnosis correct? Yes
#
# Case 20:
# Correct Diagnosis: bacterial meningitis
# LLM Output Diagnosis: **Diagnosis:** Meningitis (Bacterial Meningitis is highly suspected)
#
# **Probability:** High (70-80%)
# Is the diagnosis correct? Yes
#
# Accuracy of the diagnoses: 50.00%

# %%
# 3.1 result for NewSamples
import pandas as pd
import google.generativeai as genai
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

def initialize_genai_model(api_key, model_name="gemini-1.5-flash"):
    """Initialize and return the generative model."""
    genai.configure(api_key=api_key)
    model = genai.GenerativeModel(model_name)
    return model

def process_medical_queries(model, test_data):
    """Process medical queries by adding instructions and obtaining model responses."""
    instruction = "Suppose that you are a medical diagnosis assistant, skilled in recognizing diseases and prescribing treatments. If a patient has the following condition, give me the most probable diagnosis and the related probability and urgency and rationale for the diagnosis besides suitable treatments. Start your response with Diagnosis:"
    results = []
    stop_words = set(stopwords.words('english'))

    for index, row in test_data.iterrows():
        query = f"{instruction} {row['Patient Conditions']}"
        response = model.generate_content(query)
        texts = [part.text for part in response.parts]
        first_diagnosis = " ".join(texts).split('.')[0]

        correct_keywords = set(row['Correct Diagnosis'].lower().split()) - stop_words
        output_keywords = set(first_diagnosis.lower().split()) - stop_words
        correct_count = len(correct_keywords & output_keywords)
        percentage_correct = (correct_count / len(correct_keywords)) * 100 if correct_keywords else 0
        is_correct = percentage_correct >= 50

        results.append((index, row['Correct Diagnosis'], first_diagnosis, is_correct))
        print(f"Processed {index + 1}/{len(test_data)} cases.")

    return results

def calculate_accuracy(results):
    """Calculate the accuracy of the diagnosis predictions."""
    total_cases = len(results)
    correct_cases = sum(1 for _, _, _, is_correct in results if is_correct)
    accuracy = (correct_cases / total_cases) * 100
    return accuracy

def read_test_data(file_path):
    """Read test data from an Excel file."""
    return pd.read_excel(file_path)

# API Key and Model Name
genai.configure(api_key="AIzaSyCfWXVgeNxl3DrtkqqnIK4JegZHqrf3WZg")
model = genai.GenerativeModel(model_name="tunedModels/setting312-66toyqfk26l7")

# Read Test Data from Excel
file_path = 'Test_Data.xlsx'
test_data = read_test_data(file_path)

# Process the test data with the model
diagnoses_results = process_medical_queries(model, test_data)

# Print results
for index, correct_diagnosis, first_diagnosis, is_correct in diagnoses_results:
    print(f"Case {index + 1}:")
    print(f"Correct Diagnosis: {correct_diagnosis}")
    print(f"LLM Output Diagnosis: {first_diagnosis}")
    print(f"Is the diagnosis correct? {'Yes' if is_correct else 'No'}\n")

# Calculate and print the accuracy
accuracy = calculate_accuracy(diagnoses_results)
print(f"Accuracy of the diagnoses: {accuracy:.2f}%")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/zhangxijing/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Processed 1/20 cases.
# Processed 2/20 cases.
# Processed 3/20 cases.
# Processed 4/20 cases.
# Processed 5/20 cases.
# Processed 6/20 cases.
# Processed 7/20 cases.
# Processed 8/20 cases.
# Processed 9/20 cases.
# Processed 10/20 cases.
# Processed 11/20 cases.
# Processed 12/20 cases.
# Processed 13/20 cases.
# Processed 14/20 cases.
# Processed 15/20 cases.
# Processed 16/20 cases.
# Processed 17/20 cases.
# Processed 18/20 cases.
# Processed 19/20 cases.
# Processed 20/20 cases.
# Case 1:
# Correct Diagnosis: Cerebral Malaria
# LLM Output Diagnosis: Diagnosis: Trypanosoma brucei
#
# * Probability: High
# * Urgency: Immediate
# * Rationale:
#
#     * The patient recently traveled to Central Africa, an endemic area for African trypanosomiasis (also known as sleeping sickness), and presented with altered mental status and seizures
# Is the diagnosis correct? No
#
# Case 2:
# Correct Diagnosis: Sepsis
# LLM Output Diagnosis: Diagnosis:
#
# * Severe Sepsis with Septic Shock
#
# Probability: High
# * Rationale:
#     * The patient presented with hypothermia, tachycardia, and leukocytosis
#     * The urine culture confirmed sepsis, and the patient was started on aggressive IV hydration and broad-spectrum antibiotics
#     * Symptoms of systemic inflammation and hemodynamic instability
#
# Urgency: Critical
# * Rationale: Untreated sepsis can rapidly lead to multi-organ dysfunction and death
# Is the diagnosis correct? Yes
#
# Case 3:
# Correct Diagnosis: type I necrotizing fasciitis, sepsis
# LLM Output Diagnosis: Diagnosis:
#
# * Acute Perforated Appendicitis
#
# Probability: High
# * The abdominal CT scan clearly shows air in soft tissues, a retroperitoneal collection, a distally enlarged appendix with perforation, and communication with the collection
# Is the diagnosis correct? No
#
# Case 4:
# Correct Diagnosis: Septic arthritis, impending avascular necrosis, brucella infection
# LLM Output Diagnosis: Diagnosis: Septic Arthritis
#
# * Probability: Very High
# * Urgency: High
# * Rationale: The patients presentation of fever, joint pain, and inability to bear weight, along with history of minor trauma and living on a farm with livestock, suggests a septic arthritis
# Is the diagnosis correct? No
#
# Case 5:
# Correct Diagnosis: sepsis, cellulitis, aortitis, tricuspid insufficiency, septic vegetation, endocarditis
# LLM Output Diagnosis: Diagnosis:
#
# Sepsis
#
# Probability: Very High
# Urgency: Critical
# Rationale:
#
# * Presentation: The patient presents with fever, cold chills, hemodynamic instability, and a history of alcohol and benzodiazepine use (increasing susceptibility to infections)
# Is the diagnosis correct? No
#
# Case 6:
# Correct Diagnosis: salmonella minor infection, sepsis, mycotic aortic aneurysm, aortitis, abscess, drug allergy
# LLM Output Diagnosis: Diagnosis: Salmonella aortitis and paraaortic abscess
#
# * Probability: High
# * Urgency: Critical
# * Rationale:
#
# The presence of infective aortitis, paraaortic abscess, and mycotic aneurysm in the CT scan along with blood and abscess cultures growing Salmonella Choleraesuis strongly suggest this diagnosis
# Is the diagnosis correct? No
#
# Case 7:
# Correct Diagnosis:  indigestion
# LLM Output Diagnosis: Diagnosis: Vasovagal Syncope
#
# * Probability: High
# * Urgency: Low to Moderate
# * Rationale: The patient presents with epigastric pain after ingesting a cold beverage, followed by syncope (fainting) without chest pain
# Is the diagnosis correct? No
#
# Case 8:
# Correct Diagnosis: urosepsis
# LLM Output Diagnosis: Diagnosis: Severe Urinary Tract Infection (UTI) with Possible Complications
#
# * Probability: High
# * Urgency: Immediate (critical)
# * Rationale: The patient presents with classic symptoms of UTI (fevers, burning urination, pain) and physical examination findings (tenderness to palpation), confirmed by urinalysis results showing significant leukocytes, blood, and leukocyte esterase
# Is the diagnosis correct? No
#
# Case 9:
# Correct Diagnosis: Septic arthritis
# LLM Output Diagnosis: Diagnosis: Septic Arthritis of Bilateral Shoulder Joints
#
# * Probability: Very High
# * Urgency: Critical
# * Rationale: The imaging of the shoulders indicates moderate fluid within the joint spaces, and blood cultures grew methicillin-sensitive Staphylococcus aureus, a common cause of septic arthritis
# Is the diagnosis correct? Yes
#
# Case 10:
# Correct Diagnosis: Hemophagocytic Lymphohistiocytosis (HLH)
#
# LLM Output Diagnosis: Diagnosis:
#
# * Hemophagocytic Lymphohistiocytosis (HLH) with secondary Rickettsia infection
#
# Probability: Very High (meets HLH-2004 criteria, confirmed by PMseq-DNA testing showing Rickettsia presence)
#
# Urgency: High (Requires immediate and intensive care due to life-threatening multi-organ dysfunction)
#
# Rationale: The patient presents with several key characteristics of HLH including high fever, cytopenia affecting multiple lineages, elevated ferritin and CD25 levels, decreased NK cell activity, and hemophagocytic cells in bone marrow
# Is the diagnosis correct? Yes
#
# Case 11:
# Correct Diagnosis: periorbital cellulitis
# LLM Output Diagnosis: Diagnosis: Subcutaneous Emphysema
#
# * Probability: High
# * Urgency: Moderate
# * Rationale: The presence of crepitation in the left periorbital area, diffuse air in the left orbital soft tissue revealed by CT, and the absence of gas bubbles within the superior ophthalmic vein (superior orbital fissure) or retinal or choroidal detachment in the CT scan are characteristic of subcutaneous emphysema
# Is the diagnosis correct? Yes
#
# Case 12:
# Correct Diagnosis: cardio-embolism, ischemic stroke
# LLM Output Diagnosis: Diagnosis:
#
# * Ischemic Stroke
#
# Probability: High
#
# Urgency: Critical
#
# Rationale:
#
# - Sudden onset of left hemiparesis and vertigo
# - Previous history of stroke in 2015
# - Neurologic examination revealing mild left hemiparesis, vertical nystagmus, right internuclear ophthalmoplegia, dysarthria, and dysmetria
# - Imaging studies (CT angiography) showing hypoplasia of vertebral arteries and a persistent trigeminal artery (PTA)
# - Absence of hemorrhage on CT scan
# - Early administration of rt-PA, which is appropriate for ischemic stroke
#
# Suitable Treatments:
# - Early administration of rt-PA within two hours of symptom onset
# - Supportive care, including monitoring of vital signs, blood sugar levels, and anticoagulation status
# - Rehabilitation to address residual neurological deficits (physical, occupational, and speech therapy)
# - Regular follow-up with a healthcare provider to monitor for any recurrence or residual symptoms
# - Appropriate management of hypertension and dyslipidemia to minimize the risk of future cardiovascular eventsDiagnosis: Ischemic Stroke
#
# Probability: Very High
#
# Urgency: Emergency
#
# Rationale:
#
# The sudden onset of left hemiparesis and vertigo, the patients history of an anterior circulation right hemispheric stroke, and the presence of mild left hemiparesis, vertical nystagmus, right internuclear ophthalmoplegia, dysarthria, and dysmetria are consistent with a new ischemic stroke
# Is the diagnosis correct? Yes
#
# Case 13:
# Correct Diagnosis: UC re-activation
# LLM Output Diagnosis: Diagnosis: ANCA-associated vasculitis
#
# * Probability: Very high
# * Urgency: Critical
# * Rationale: The patient presents with multiple clinical signs and symptoms consistent with ANCA-associated vasculitis, including blistering purpura, mononeuritis multiplex, fever, and gastrointestinal involvement
# Is the diagnosis correct? No
#
# Case 14:
# Correct Diagnosis: viral myocarditis, viral sepsis
# LLM Output Diagnosis: Diagnosis:
#
# * Myocarditis
#
# Probability: Very High
# * The patient presented with symptoms consistent with myocarditis (chest pain, shortness of breath, syncope, low ejection fraction)
# Is the diagnosis correct? No
#
# Case 15:
# Correct Diagnosis:  Pseudomonas aeruginosa diarrhea
# LLM Output Diagnosis: Diagnosis:  Myxedema Coma with Secondary Complications
#
# * Probability: High
# * Urgency: Immediate
# * Rationale: The patient presented with altered mental status (GCS 3), history of hypothyroidism, and need for intubation
# Is the diagnosis correct? No
#
# Case 16:
# Correct Diagnosis: Intrabullous hemorrhage
# LLM Output Diagnosis: Diagnosis: Acute COPD Exacerbation with Pneumonia and Infection
#
# * Probability: High, given the history of COPD, recent onset of chest pain, cough, and hemoptysis
# * Rationale: The patient has known COPD, and the chest radiograph and CT scan confirm the presence of emphysema
# Is the diagnosis correct? No
#
# Case 17:
# Correct Diagnosis: sexual disorder secondary to therapy
# LLM Output Diagnosis:
# Is the diagnosis correct? No
#
# Case 18:
# Correct Diagnosis: unprovoked superficial thrombophlebitis
# LLM Output Diagnosis: Diagnosis: Renal Cell Carcinoma
#
# * Probability: High (Diagnosis confirmed by biopsy)
# * Urgency: High (High-grade renal cell carcinoma with metastatic potential)
# * Rationale: Multiple episodes of unprovoked superficial thrombophlebitis, raised gamma-GT, and CT-scan revealing a solid mass in the left kidney, confirmed by biopsy as renal cell carcinoma
# Is the diagnosis correct? Yes
#
# Case 19:
# Correct Diagnosis: NOH
# LLM Output Diagnosis: Diagnosis: Neurocardiogenic Syncope (nOH)
#
# * Probability: High
# * Urgency: Immediate
# * Rationale: The combination of orthostatic hypotension, confirmed by tilt-table testing and Valsalva manoeuvre, along with clinical presentation and family reports of symptoms prior to syncope, strongly suggests nOH
# Is the diagnosis correct? Yes
#
# Case 20:
# Correct Diagnosis: Carotid Sinus Hypersensitivity (CSS):
#
# LLM Output Diagnosis: Diagnosis: Carotid Sinus Hypersensitivity
#
# * Probability: Very High
# * Urgency: Moderate
# * Rationale: The patient's syncope occurring during shaving of the neck, history of past syncopal episodes, and baseline bradycardia strongly suggest carotid sinus syndrome (CSS)
# Is the diagnosis correct? Yes
#
# Accuracy of the diagnoses: 40.00%

# %%
# 3.1 result for for FineTunedSample
import pandas as pd
import google.generativeai as genai
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

def initialize_genai_model(api_key, model_name="gemini-1.5-flash"):
    """Initialize and return the generative model."""
    genai.configure(api_key=api_key)
    model = genai.GenerativeModel(model_name)
    return model

def process_medical_queries(model, test_data):
    """Process medical queries by adding instructions and obtaining model responses."""
    instruction = "Suppose that you are a medical diagnosis assistant, skilled in recognizing diseases and prescribing treatments. If a patient has the following condition, give me the most probable diagnosis and the related probability and urgency and rationale for the diagnosis besides suitable treatments. Start your response with Diagnosis:"
    results = []
    stop_words = set(stopwords.words('english'))

    for index, row in test_data.iterrows():
        query = f"{instruction} {row['Patient Conditions']}"
        response = model.generate_content(query)
        texts = [part.text for part in response.parts]
        first_diagnosis = " ".join(texts).split('.')[0]

        correct_keywords = set(row['Correct Diagnosis'].lower().split()) - stop_words
        output_keywords = set(first_diagnosis.lower().split()) - stop_words
        correct_count = len(correct_keywords & output_keywords)
        percentage_correct = (correct_count / len(correct_keywords)) * 100 if correct_keywords else 0
        is_correct = percentage_correct >= 50

        results.append((index, row['Correct Diagnosis'], first_diagnosis, is_correct))
        print(f"Processed {index + 1}/{len(test_data)} cases.")

    return results

def calculate_accuracy(results):
    """Calculate the accuracy of the diagnosis predictions."""
    total_cases = len(results)
    correct_cases = sum(1 for _, _, _, is_correct in results if is_correct)
    accuracy = (correct_cases / total_cases) * 100
    return accuracy

def read_test_data(file_path, sheet_name=None):
    """Read test data from an Excel file, optionally specifying a sheet."""
    return pd.read_excel(file_path, sheet_name=sheet_name)

# API Key and Model Name
genai.configure(api_key="AIzaSyCfWXVgeNxl3DrtkqqnIK4JegZHqrf3WZg")
model = genai.GenerativeModel(model_name="tunedModels/setting312-66toyqfk26l7")

# Read Test Data from Excel
file_path = 'Test_Data.xlsx'
sheet_name = 'FineTunedSamples'  # Specify the sheet name here
test_data = read_test_data(file_path, sheet_name)

# Process the test data with the model
diagnoses_results = process_medical_queries(model, test_data)

# Print results
for index, correct_diagnosis, first_diagnosis, is_correct in diagnoses_results:
    print(f"Case {index + 1}:")
    print(f"Correct Diagnosis: {correct_diagnosis}")
    print(f"LLM Output Diagnosis: {first_diagnosis}")
    print(f"Is the diagnosis correct? {'Yes' if is_correct else 'No'}\n")

# Calculate and print the accuracy
accuracy = calculate_accuracy(diagnoses_results)
print(f"Accuracy of the diagnoses: {accuracy:.2f}%")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/zhangxijing/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Processed 1/20 cases.
# Processed 2/20 cases.
# Processed 3/20 cases.
# Processed 4/20 cases.
# Processed 5/20 cases.
# Processed 6/20 cases.
# Processed 7/20 cases.
# Processed 8/20 cases.
# Processed 9/20 cases.
# Processed 10/20 cases.
# Processed 11/20 cases.
# Processed 12/20 cases.
# Processed 13/20 cases.
# Processed 14/20 cases.
# Processed 15/20 cases.
# Processed 16/20 cases.
# Processed 17/20 cases.
# Processed 18/20 cases.
# Processed 19/20 cases.
# Processed 20/20 cases.
# Case 1:
# Correct Diagnosis: Pertussis
# LLM Output Diagnosis: Diagnosis: Pertussis (Whooping Cough)
#
# * Probability: High
# * Urgency: High
# * Rationale:
#     * The dry, intense, frequent cough, followed by productive cough with vomiting, weakness, and mild fever are characteristic of pertussis
# Is the diagnosis correct? Yes
#
# Case 2:
# Correct Diagnosis: COPD
# LLM Output Diagnosis: Diagnosis: Chronic Obstructive Pulmonary Disease (COPD)
#
# * Probability: High
# * Urgency: High
# * Rationale:
#
# - History of recurrent pneumonia, persistent productive cough, difficulty in breathing, and easy fatigue are consistent with chronic lung disease
# Is the diagnosis correct? No
#
# Case 3:
# Correct Diagnosis: Community-Acquired Pneumonia (CAP)
# LLM Output Diagnosis: Diagnosis: Community-Acquired Pneumonia
#
# * Probability: Very high
# * Urgency: Immediate medical attention required
# * Rationale: The patient's presentation aligns closely with CAP, including fever, rigors, productive cough, pleuritic chest pain, dyspnea, tachypnea, tachycardia, and rales on lung auscultation
# Is the diagnosis correct? Yes
#
# Case 4:
# Correct Diagnosis: Acute bacterial Prostatitis
# LLM Output Diagnosis: Diagnosis: Acute bacterial prostatitis
#
# * Probability: Very high
# * Urgency: High
# * Rationale: The patient presents with symptoms typical of prostatitis (painful urination, fever, sense of warming, sickness) with additional signs of inflammation (erythema at neck and chest) and a positive history of urinary retention, a condition often associated with prostatitis
# Is the diagnosis correct? Yes
#
# Case 5:
# Correct Diagnosis: Hairy cell leukemia variant
# LLM Output Diagnosis: Diagnosis: Hairy Cell Leukemia (HCL)
#
# * Probability: Very High
# * Rationale: The patient presents with persistent absolute lymphocytosis, splenomegaly, and atypical lymphocytes on peripheral blood smear with cytoplasmic projections
# Is the diagnosis correct? Yes
#
# Case 6:
# Correct Diagnosis: bacterial cystitis, dysbiosis
# LLM Output Diagnosis:
# Is the diagnosis correct? No
#
# Case 7:
# Correct Diagnosis: fatty liver disease
# LLM Output Diagnosis: Diagnosis:
#
# * Non-alcoholic fatty liver disease (NAFLD)
#
# Rationale:
#
# * The patient is overweight, eats a lot of fatty food, and has a family history of Alzheimer's and stroke
# Is the diagnosis correct? Yes
#
# Case 8:
# Correct Diagnosis: urosepsis
# LLM Output Diagnosis: Diagnosis: Urinary Tract Infection-Induced Sepsis
#
# * Probability: Very High
# * Urgency: High (Emergent)
# * Rationale: The patient presents with classic signs and symptoms of sepsis including fever, tachycardia, diaphoresis, and altered mental status
# Is the diagnosis correct? No
#
# Case 9:
# Correct Diagnosis: Septick shock
# LLM Output Diagnosis: Diagnosis: Vibrio metschnikovii infection
#
# * Probability: High
# * Urgency: Immediate
# * Rationale: Vibrio metschnikovii, a gram-negative bacterium, was identified in blood samples using matrix-assisted laser desorption/ionization time-of-flight mass spectrometry
# Is the diagnosis correct? No
#
# Case 10:
# Correct Diagnosis: gastroenteritis
# LLM Output Diagnosis: Diagnosis: Colic
#
# * Probability: High
# * Urgency: Moderate
# * Rationale: The patient presents with abdominal pain described as colic, which is a characteristic of spasmodic pain in the abdominal area
# Is the diagnosis correct? No
#
# Case 11:
# Correct Diagnosis: Septick shock
# LLM Output Diagnosis: Diagnosis:
#
# * Severe Septic Shock
#
# Probability: High
# * The patient presented with hemodynamic instability, severe hypotension requiring catecholaminergic therapy, metabolic acidosis with elevated lactate levels, organ dysfunction (renal failure, hepatic impairment), and positive blood cultures for S
# Is the diagnosis correct? Yes
#
# Case 12:
# Correct Diagnosis: COVID-19 associated stroke
# LLM Output Diagnosis: Diagnosis: Posterior Circulation (AOP) Stroke
#
# * Probability: High
# * Urgency: Critical
# * Rationale:
#
# The MRI with MRA demonstrated bilateral medial thalamus and midbrain infarcts with nonvisualization of the posterior cerebral artery, indicative of a posterior circulation stroke
# Is the diagnosis correct? No
#
# Case 13:
# Correct Diagnosis: sexual disorder secondary to therapy
# LLM Output Diagnosis: Diagnosis:
#
# * Side Effects of Galcanezumab
#
# Rationale:
# The patient experienced a loss of libido and difficulty achieving orgasm shortly after starting galcanezumab treatment for migraines
# Is the diagnosis correct? No
#
# Case 14:
# Correct Diagnosis: Lyme carditis
# LLM Output Diagnosis: Diagnosis:
#
# * Probability: Very High
# * Urgency: Critical
# * Rationale: The presence of an insect bite, followed by chills, sweats, myalgia, and fatigue, along with the subsequent development of AV block and hemodynamic instability, strongly suggests a case of Lyme carditis
# Is the diagnosis correct? Yes
#
# Case 15:
# Correct Diagnosis: Metformin side effects
# LLM Output Diagnosis: Diagnosis:
#
# * Septic shock
#
# Probability: High
# * Due to the presence of polymicrobial bacteremia (including vancomycin-resistant Enterococcus faecium, Enterococcus faecalis, and Staphylococcus epidermidis) and subsequent development of severe acute kidney injury (AKI), hypotension, and metabolic acidosis, despite initial treatment with broad-spectrum antibiotics
# Is the diagnosis correct? No
#
# Case 16:
# Correct Diagnosis: AIS
# LLM Output Diagnosis: Diagnosis: Acute Ischemic Stroke
#
# * Probability: Very High
# * Urgency: Critical
# * Rationale: The presence of acute ischemic infarcts in bilateral cerebellar hemispheres, superior vermis, and PCA distribution, as evidenced by MRI brain diffusion weighted images, along with the findings of focal loss of gray-white differentiation involving the left temporal, occipital lobe in a left PCA distribution on CT angiogram of head and neck, suggest acute ischemic stroke
# Is the diagnosis correct? No
#
# Case 17:
# Correct Diagnosis: Galcanezumab-induced sexual dysfunction
# LLM Output Diagnosis:
# Is the diagnosis correct? No
#
# Case 18:
# Correct Diagnosis: infective pharyngitis
# LLM Output Diagnosis: Diagnosis: Viral Pharyngitis/Pharyngitis
#
# * Probability: Very High
# * Urgency: Moderate
# * Rationale: The presence of fever, pharyngeal pain, and throat pain for 3 days, redness and swelling in the pharynx with no throat plaques, and temporary relief with ibuprofen aligns well with a viral pharyngitis
# Is the diagnosis correct? Yes
#
# Case 19:
# Correct Diagnosis: sexual disorder secondary to therapy
# LLM Output Diagnosis: Diagnosis: Sexual Arousal Disorder due to Galcanezumab Treatment
#
# * Probability: High
# * Urgency: Moderate
# * Rationale: The patient reported a decrease in libido after starting galcanezumab for migraine treatment
# Is the diagnosis correct? Yes
#
# Case 20:
# Correct Diagnosis: bacterial meningitis
# LLM Output Diagnosis: Diagnosis: Meningitis
#
# * Probability: Very High (Given the neurological findings, fever, headache, neck pain, chills, nausea, vomiting, lethargy, and positive Kernig's sign)
# * Urgency: Immediate (requires rapid intervention due to life-threatening potential)
# * Rationale:
#
# Suitable Treatments:
# * Broad-spectrum intravenous antibiotics (e
# Is the diagnosis correct? Yes
#
# Accuracy of the diagnoses: 50.00%

# %%
# 3.2 result for NewSamples
import pandas as pd
import google.generativeai as genai
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

def initialize_genai_model(api_key, model_name="gemini-1.5-flash"):
    """Initialize and return the generative model."""
    genai.configure(api_key=api_key)
    model = genai.GenerativeModel(model_name)
    return model

def process_medical_queries(model, test_data):
    """Process medical queries by adding instructions and obtaining model responses."""
    instruction = "Suppose that you are a medical diagnosis assistant, skilled in recognizing diseases and prescribing treatments. If a patient has the following condition, give me the most probable diagnosis and the related probability and urgency and rationale for the diagnosis besides suitable treatments. Start your response with Diagnosis:"
    results = []
    stop_words = set(stopwords.words('english'))

    for index, row in test_data.iterrows():
        query = f"{instruction} {row['Patient Conditions']}"
        response = model.generate_content(query)
        texts = [part.text for part in response.parts]
        first_diagnosis = " ".join(texts).split('.')[0]

        correct_keywords = set(row['Correct Diagnosis'].lower().split()) - stop_words
        output_keywords = set(first_diagnosis.lower().split()) - stop_words
        correct_count = len(correct_keywords & output_keywords)
        percentage_correct = (correct_count / len(correct_keywords)) * 100 if correct_keywords else 0
        is_correct = percentage_correct >= 50

        results.append((index, row['Correct Diagnosis'], first_diagnosis, is_correct))
        print(f"Processed {index + 1}/{len(test_data)} cases.")

    return results

def calculate_accuracy(results):
    """Calculate the accuracy of the diagnosis predictions."""
    total_cases = len(results)
    correct_cases = sum(1 for _, _, _, is_correct in results if is_correct)
    accuracy = (correct_cases / total_cases) * 100
    return accuracy

def read_test_data(file_path):
    """Read test data from an Excel file."""
    return pd.read_excel(file_path)

# API Key and Model Name
genai.configure(api_key="AIzaSyCfWXVgeNxl3DrtkqqnIK4JegZHqrf3WZg")
model = genai.GenerativeModel(model_name="tunedModels/setting322-8kk4z58v46bb")

# Read Test Data from Excel
file_path = 'Test_Data.xlsx'
test_data = read_test_data(file_path)

# Process the test data with the model
diagnoses_results = process_medical_queries(model, test_data)

# Print results
for index, correct_diagnosis, first_diagnosis, is_correct in diagnoses_results:
    print(f"Case {index + 1}:")
    print(f"Correct Diagnosis: {correct_diagnosis}")
    print(f"LLM Output Diagnosis: {first_diagnosis}")
    print(f"Is the diagnosis correct? {'Yes' if is_correct else 'No'}\n")

# Calculate and print the accuracy
accuracy = calculate_accuracy(diagnoses_results)
print(f"Accuracy of the diagnoses: {accuracy:.2f}%")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/zhangxijing/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Processed 1/20 cases.
# Processed 2/20 cases.
# Processed 3/20 cases.
# Processed 4/20 cases.
# Processed 5/20 cases.
# Processed 6/20 cases.
# Processed 7/20 cases.
# Processed 8/20 cases.
# Processed 9/20 cases.
# Processed 10/20 cases.
# Processed 11/20 cases.
# Processed 12/20 cases.
# Processed 13/20 cases.
# Processed 14/20 cases.
# Processed 15/20 cases.
# Processed 16/20 cases.
# Processed 17/20 cases.
# Processed 18/20 cases.
# Processed 19/20 cases.
# Processed 20/20 cases.
# Case 1:
# Correct Diagnosis: Cerebral Malaria
# LLM Output Diagnosis: Diagnosis:
#
# * Central Nervous System Infection
#
# Probability: High
# * The patient presented with an altered mental status, seizures, and a history of international travel with exposure to potential infectious environments
# Is the diagnosis correct? No
#
# Case 2:
# Correct Diagnosis: Sepsis
# LLM Output Diagnosis: Diagnosis:
#
# * **Diagnosis:** Sepsis (Severe)
# * **Probability:** High
# * **Urgency:** Critical - the patient is hypothermic, tachycardic, and has significant leukocytosis
# * **Rationale:** The patient has significant leukocytosis, hyponatremia, and a cloudy urine analysis with leukocyte esterase and numerous white blood cells
# Is the diagnosis correct? Yes
#
# Case 3:
# Correct Diagnosis: type I necrotizing fasciitis, sepsis
# LLM Output Diagnosis: Diagnosis: Appendicitis with perforation and abscess formation
#
# Probability: High
#
# Urgency: Emergency
#
# Rationale: The patients symptoms of right lumbar pain, erythema on the right flank and lumbar region, subcutaneous crepitus, elevated white blood cell count with polymorphonuclear cells, and an abdominal CT scan showing an enlarged and perforated appendix with air in the soft tissues and a retroperitoneal collection support this diagnosis
# Is the diagnosis correct? No
#
# Case 4:
# Correct Diagnosis: Septic arthritis, impending avascular necrosis, brucella infection
# LLM Output Diagnosis: Diagnosis: Septic Arthritis
#
# Probability: High
# Urgency: Critical
#
# Rationale:
# * The patient presents with fever, severe hip pain, limited hip motion, and positive blood culture
# Is the diagnosis correct? No
#
# Case 5:
# Correct Diagnosis: sepsis, cellulitis, aortitis, tricuspid insufficiency, septic vegetation, endocarditis
# LLM Output Diagnosis: Diagnosis:
#
# * Acute Bacterial Meningitis (ABM)
#
# Probability:
#
# * High (Moderate-High, considering clinical presentation and lab findings)
#
# Urgency:
# * Critical: Requires immediate medical intervention and aggressive treatment
#
# Rationale:
# * Patient presented with fever, cold chills, tachycardia, altered mental status, and an enlarged mediastinum on chest radiography, which is strongly suggestive of ABM
# Is the diagnosis correct? No
#
# Case 6:
# Correct Diagnosis: salmonella minor infection, sepsis, mycotic aortic aneurysm, aortitis, abscess, drug allergy
# LLM Output Diagnosis: Diagnosis:
#
# * **Infective Aortitis**
#
# Probability: Very High
# * The patient has clinical findings suggestive of infective aortitis including prolonged fever, chills, abdominal pain, and positive blood cultures
# Is the diagnosis correct? No
#
# Case 7:
# Correct Diagnosis:  indigestion
# LLM Output Diagnosis: Diagnosis: Syncope
#
# * Probability: High
# * Urgency: High
# * Rationale: The patient, after consuming a cold beverage, experiences epigastric pain followed by syncope
# Is the diagnosis correct? No
#
# Case 8:
# Correct Diagnosis: urosepsis
# LLM Output Diagnosis: Diagnosis: Urinary Tract Infection (UTI)
#
# Probability: High
#
# Urgency: High, escalated to ED due to suspicion of a severe UTI
#
# Rationale: Subjective fevers, burning on urination, penile and testicular pain, tenderness to palpation at the base of the penis and testicular area, cloudy urinalysis showing +20 WBCs, large blood, trace leukocyte esterase, and negative nitrites all support a urinary tract infection
# Is the diagnosis correct? No
#
# Case 9:
# Correct Diagnosis: Septic arthritis
# LLM Output Diagnosis: Diagnosis: MSSA Bacteremia with Epididymo-Orchitis and Septic Arthritis
#
# * Probability: High (as confirmed by blood cultures and joint fluid analysis)
# * Urgency: Critical (due to septic shock and multi-organ involvement)
# * Rationale: The patient's initial symptoms, including fever, tachycardia, and high inflammatory markers, along with positive blood cultures and joint fluid samples, point to a systemic infection
# Is the diagnosis correct? Yes
#
# Case 10:
# Correct Diagnosis: Hemophagocytic Lymphohistiocytosis (HLH)
#
# LLM Output Diagnosis: Diagnosis:
#
# * Rickettsia-Induced Multiple Organ Dysfunction Syndrome
#
# Probability: Very High
# * Due to elevated inflammatory markers (CRP, PCT), blood tests showing significant reduction in WBC, lymphocytes, and platelets, positive serological tests for hepatitis B and confirmed presence of Rickettsia in PMseq-DNA testing
# Is the diagnosis correct? No
#
# Case 11:
# Correct Diagnosis: periorbital cellulitis
# LLM Output Diagnosis: Diagnosis: Orbital Emphysema
#
# * Probability: High
# * Urgency: High
# * Rationale: The presence of periorbital swelling and crepitation in the left periorbital area combined with orbital CT findings of diffuse air in the left orbital soft tissue strongly suggests orbital emphysema
# Is the diagnosis correct? Yes
#
# Case 12:
# Correct Diagnosis: cardio-embolism, ischemic stroke
# LLM Output Diagnosis: Diagnosis:  Vertebrobasilar Stroke
#
# * Probability: High
# * Urgency: Immediate
# * Rationale:
#
# The patient presented with sudden onset of left hemiparesis and vertigo, followed by the neurologic examination revealing mild left hemiparesis with facial involvement and crural predominance, vertical nystagmus, right internuclear ophthalmoplegia, dysarthria, and dysmetria on the left arm
# Is the diagnosis correct? No
#
# Case 13:
# Correct Diagnosis: UC re-activation
# LLM Output Diagnosis: Diagnosis: ANCA-Associated Vasculitis (Microscopic Polyangiitis)
#
# * Probability: High
# * Urgency: Critical
# * Rationale: This diagnosis is strongly supported by the presence of multiple clinical signs and test results:
#     * Leukocytoclastic vasculitis in skin biopsies
#     * Elevated CRP levels (a reliable indicator of inflammation)
#     * p-ANCA positivity in serum
#     * Characteristic histopathologic findings (necrosis of the mucosa and submucosa with thrombosis, neutrophils and nuclear debris)
#     * Involvement of multiple systems (skin, colon, peripheral nerves), particularly the presence of purpura, mononeuritis multiplex, and fever
#     * Absence of granulomatous changes or immune deposits, which rules out granulomatosis with polyangiitis
#
# Suitable Treatments:
# * The current treatment includes high-dose intravenous prednisolone (60 mg/day) and intravenous cyclophosphamide (15 mg/kg at week 0-2-4, followed by once every 3 weeks until 3 months of stable remission)
# * It also includes discontinuation of infliximab and azathioprine
# * A switch to mesalamine monotherapy for the UC
# * Prednisolone to be tapered and stopped after 4 months and cyclophosphamide to be discontinued after seven infusions
# *  Oral methotrexate (20 mg once weekly) was started to reduce the risk of vasculitis recurrence
# *  Re-introduction of infliximab, initially in three induction doses (5 mg/kg) over 6 weeks, after achieving remission
# *  Escalation of infliximab to 10 mg/kg every 8 weeks upon measurement of a suboptimal infliximab trough level
# Is the diagnosis correct? Yes
#
# Case 14:
# Correct Diagnosis: viral myocarditis, viral sepsis
# LLM Output Diagnosis: Diagnosis: Myocarditis with Pericarditis
#
# * Probability: High
# * Urgency: Critical
# * Rationale: The ECG findings (low-voltage QRS complexes and T-wave inversions) support the diagnosis of myocarditis, along with the increased cardiac troponin level and echocardiogram results showing LV dysfunction, pericardial effusion, and concentric LVH
# Is the diagnosis correct? No
#
# Case 15:
# Correct Diagnosis:  Pseudomonas aeruginosa diarrhea
# LLM Output Diagnosis: Diagnosis:
#
# * Severe Hypothyroidism (Myxedema Coma)
#
# Probability: High
# * The patient’s medical history includes hypothyroidism and he presented with altered mental status, GCS 3, and required intubation for airway protection
# Is the diagnosis correct? No
#
# Case 16:
# Correct Diagnosis: Intrabullous hemorrhage
# LLM Output Diagnosis: Diagnosis: Pneumonia (and potential COPD Exacerbation)
#
# * Probability: High
# * Urgency: High (Due to haemoptysis and severe chest pain, requiring immediate treatment and surveillance)
# * Rationale:
#     * Initial chest X-ray consistent with large bullae and airspace disease
#     * Positive urine sample for 23 valent pneumococcal antigen
#     * Symptoms such as productive cough, chest pain, and increased white blood cell count
# * Treatments:
#     * Antibiotics (Azithromycin, Ceftriaxone), anti-inflammatory agents (Prednisone)
#     * Close monitoring, support, and adjustments based on clinical response
#
# Suitable treatments:
# * Broad spectrum antibiotics (e
# Is the diagnosis correct? No
#
# Case 17:
# Correct Diagnosis: sexual disorder secondary to therapy
# LLM Output Diagnosis:
# Is the diagnosis correct? No
#
# Case 18:
# Correct Diagnosis: unprovoked superficial thrombophlebitis
# LLM Output Diagnosis: Diagnosis:
#
# * Superficial Thrombophlebitis (Diagnosis by Exclusion)
#
# Probability: High
#
# Urgency: High
#
# Rationale:
#
# * The patient has a history of multiple episodes of superficial thrombophlebitis, confirmed by compression ultrasonography
# Is the diagnosis correct? Yes
#
# Case 19:
# Correct Diagnosis: NOH
# LLM Output Diagnosis: Diagnosis: Neurogenic Orthostatic Hypotension (nOH)
#
# Probability: High
# * Rationale: The patient’s history of syncope that only occurs while standing, the timing variability, appearance changes preceding fainting, rapid recovery of consciousness after syncope, increasing frequency, and family reporting of ‘looking like he was about to faint’ align well with nOH
# Is the diagnosis correct? Yes
#
# Case 20:
# Correct Diagnosis: Carotid Sinus Hypersensitivity (CSS):
#
# LLM Output Diagnosis: Diagnosis: Carotid Sinus Hypersensitivity
#
# * Probability: High (Confirmed through physical stimulation during hair cut)
# * Urgency: Moderate
# * Rationale: The syncope occurred during a trigger (shaving the neck) and the history of syncope with normal vitals and labs, the bradycardia, and normal orthostatic vitals point strongly towards CSS
# Is the diagnosis correct? Yes
#
# Accuracy of the diagnoses: 35.00%

# %%
# 3.2 result for FineTunedSample
import pandas as pd
import google.generativeai as genai
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

def initialize_genai_model(api_key, model_name="gemini-1.5-flash"):
    """Initialize and return the generative model."""
    genai.configure(api_key=api_key)
    model = genai.GenerativeModel(model_name)
    return model

def process_medical_queries(model, test_data):
    """Process medical queries by adding instructions and obtaining model responses."""
    instruction = "Suppose that you are a medical diagnosis assistant, skilled in recognizing diseases and prescribing treatments. If a patient has the following condition, give me the most probable diagnosis and the related probability and urgency and rationale for the diagnosis besides suitable treatments. Start your response with Diagnosis:"
    results = []
    stop_words = set(stopwords.words('english'))

    for index, row in test_data.iterrows():
        query = f"{instruction} {row['Patient Conditions']}"
        response = model.generate_content(query)
        texts = [part.text for part in response.parts]
        first_diagnosis = " ".join(texts).split('.')[0]

        correct_keywords = set(row['Correct Diagnosis'].lower().split()) - stop_words
        output_keywords = set(first_diagnosis.lower().split()) - stop_words
        correct_count = len(correct_keywords & output_keywords)
        percentage_correct = (correct_count / len(correct_keywords)) * 100 if correct_keywords else 0
        is_correct = percentage_correct >= 50

        results.append((index, row['Correct Diagnosis'], first_diagnosis, is_correct))
        print(f"Processed {index + 1}/{len(test_data)} cases.")

    return results

def calculate_accuracy(results):
    """Calculate the accuracy of the diagnosis predictions."""
    total_cases = len(results)
    correct_cases = sum(1 for _, _, _, is_correct in results if is_correct)
    accuracy = (correct_cases / total_cases) * 100
    return accuracy

def read_test_data(file_path, sheet_name=None):
    """Read test data from an Excel file, optionally specifying a sheet."""
    return pd.read_excel(file_path, sheet_name=sheet_name)

# API Key and Model Name
genai.configure(api_key="AIzaSyCfWXVgeNxl3DrtkqqnIK4JegZHqrf3WZg")
model = genai.GenerativeModel(model_name="tunedModels/setting322-8kk4z58v46bb")

# Read Test Data from Excel
file_path = 'Test_Data.xlsx'
sheet_name = 'FineTunedSamples'  # Specify the sheet name here
test_data = read_test_data(file_path, sheet_name)

# Process the test data with the model
diagnoses_results = process_medical_queries(model, test_data)

# Print results
for index, correct_diagnosis, first_diagnosis, is_correct in diagnoses_results:
    print(f"Case {index + 1}:")
    print(f"Correct Diagnosis: {correct_diagnosis}")
    print(f"LLM Output Diagnosis: {first_diagnosis}")
    print(f"Is the diagnosis correct? {'Yes' if is_correct else 'No'}\n")

# Calculate and print the accuracy
accuracy = calculate_accuracy(diagnoses_results)
print(f"Accuracy of the diagnoses: {accuracy:.2f}%")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/zhangxijing/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Processed 1/20 cases.
# Processed 2/20 cases.
# Processed 3/20 cases.
# Processed 4/20 cases.
# Processed 5/20 cases.
# Processed 6/20 cases.
# Processed 7/20 cases.
# Processed 8/20 cases.
# Processed 9/20 cases.
# Processed 10/20 cases.
# Processed 11/20 cases.
# Processed 12/20 cases.
# Processed 13/20 cases.
# Processed 14/20 cases.
# Processed 15/20 cases.
# Processed 16/20 cases.
# Processed 17/20 cases.
# Processed 18/20 cases.
# Processed 19/20 cases.
# Processed 20/20 cases.
# Case 1:
# Correct Diagnosis: Pertussis
# LLM Output Diagnosis: Diagnosis: Acute Bronchitis
#
# * Probability: High
# * Urgency: Moderate
# * Rationale: The patient presents with classic symptoms of acute bronchitis, including fever, weakness, dry cough that later becomes productive with catarrhal phlegm, and mild throat pain
# Is the diagnosis correct? No
#
# Case 2:
# Correct Diagnosis: COPD
# LLM Output Diagnosis: Diagnosis: Chronic Obstructive Pulmonary Disease (COPD)
#
# Probability: High
# * Rationale: The patient has several episodes of difficulty breathing, productive cough, easy fatigue, and poor appetite which are all strong indicators of COPD, especially in a non-alcoholic, non-smoking individual with a history of several antibiotic uses for pneumonia
# Is the diagnosis correct? No
#
# Case 3:
# Correct Diagnosis: Community-Acquired Pneumonia (CAP)
# LLM Output Diagnosis: Diagnosis: Community-Acquired Pneumonia (CAP)
#
# Probability: High
# Rationale:
# - High fever, rigors, productive cough, and pleuritic chest pain are cardinal symptoms of bacterial pneumonia
# - Dyspnea, tachypnea, tachycardia, malaise, and fatigue further strengthen this suspicion
# - Rales, dullness to percussion, decreased breath sounds, and decreased tactile fremitus on physical examination confirm the diagnosis of pneumonia
# - Onset with chills suggests an infectious origin, and a body temperature of 39°C further reinforces this diagnosis
#
# Urgency: High
# - Rapid onset with chills and high fever indicate a severe and rapidly progressing pneumonia
# - Dyspnea and pleuritic chest pain indicate potential fluid build-up in the lungs, posing a risk of respiratory distress
#
# Suitable Treatment:
# - Hospitalization for IV antibiotics, supportive care (fluids, analgesics, and oxygen therapy)
# - Regular monitoring of vital signs, respiratory parameters (O2 saturation, ventilation), and radiographic assessment (chest X-ray)
# - Broad-spectrum antibiotic therapy (e
# Is the diagnosis correct? Yes
#
# Case 4:
# Correct Diagnosis: Acute bacterial Prostatitis
# LLM Output Diagnosis: Diagnosis: Acute Bacterial Prostatitis
#
# * Probability: High (Considering the patient's symptoms of pain during urination, fever, and signs of inflammation)
# Is the diagnosis correct? Yes
#
# Case 5:
# Correct Diagnosis: Hairy cell leukemia variant
# LLM Output Diagnosis: Diagnosis: Chronic Lymphocytic Leukemia (CLL)
#
# * Probability: High
# * Urgency: High
# * Rationale: The patient presents with elevated WBC count and absolute lymphocyte count, atypical lymphocytes on peripheral blood smear, flow cytometry revealing a clonal B-cell population with characteristic markers (CD11c, CD20, lambda light chain), and bone marrow biopsy immunohistochemistry results further support the diagnosis of CLL
# Is the diagnosis correct? No
#
# Case 6:
# Correct Diagnosis: bacterial cystitis, dysbiosis
# LLM Output Diagnosis: Diagnosis: Urinary Tract Infection (UTI)
#
# Probability: High
# Urgency: Moderate to High
# Rationale:
#
# The patient presents with typical symptoms of a UTI, including genital burning, dysuria, and frequent urination
# Is the diagnosis correct? No
#
# Case 7:
# Correct Diagnosis: fatty liver disease
# LLM Output Diagnosis: Diagnosis:
#
# * Probability: Medium
# * Urgency: Medium
# * Rationale: The patients symptoms of abdominal pain in the right upper region, especially when combined with an enlarged liver, point to potential biliary disease
# Is the diagnosis correct? No
#
# Case 8:
# Correct Diagnosis: urosepsis
# LLM Output Diagnosis: Diagnosis: Urosepsis
#
# * Probability: Very High
# * Urgency: Emergency (Critical), patient needs prompt and intensive care
# * Rationale: The patient presented with right flank pain followed by fever, chills, and abdominal pain along with symptoms of sepsis such as fever, tachycardia, and diaphoresis
# Is the diagnosis correct? Yes
#
# Case 9:
# Correct Diagnosis: Septick shock
# LLM Output Diagnosis: Diagnosis:
#
# * Vibrio metschnikovii Sepsis
#
# Probability: High
# * The diagnosis is based on the Gram-negative bacteria confirmed by Gram-stained smears and identified as Vibrio metschnikovii through matrix-assisted laser desorption/ionization time-of-flight mass spectrometry
# Is the diagnosis correct? No
#
# Case 10:
# Correct Diagnosis: gastroenteritis
# LLM Output Diagnosis: Diagnosis: Probable Acute Cholecystitis
#
# Probability: Moderate to High (60-80%)
#
# Urgency: Moderate to High (Immediate surgery is needed to avoid complications)
#
# Rationale:
#
# * History: The patient presents with abdominal pain, which she describes as colic, and has experienced diarrhoea and vomiting, suggesting a biliary origin
# Is the diagnosis correct? No
#
# Case 11:
# Correct Diagnosis: Septick shock
# LLM Output Diagnosis: Diagnosis:
#
# * Septic Shock
#
# Probability: High
# * Rationale: The patient presents with severe hemodynamic instability, elevated lactate levels, signs of organ dysfunction (anuria, acute renal failure), metabolic acidosis, and disseminated intravascular coagulation (DIC), all typical features of septic shock
# Is the diagnosis correct? Yes
#
# Case 12:
# Correct Diagnosis: COVID-19 associated stroke
# LLM Output Diagnosis: Diagnosis: COVID-19-associated acute confusional state (delirium)
#
# * Probability: High
# * Urgency: Very High (patient underwent deterioration with pupillary asymmetry and intubation)
# * Rationale:
# * Initial blood investigations showed no significant abnormalities
# Is the diagnosis correct? No
#
# Case 13:
# Correct Diagnosis: sexual disorder secondary to therapy
# LLM Output Diagnosis: Diagnosis:
#
# * Migraine
#
# Probability: High
#
# Urgency: Moderate-High (due to severe and persistent migraine symptoms)
#
# Rationale:
# * The patient suffers from chronic migraine without aura and migraine with aura, suggesting a complex migraine pattern
# Is the diagnosis correct? No
#
# Case 14:
# Correct Diagnosis: Lyme carditis
# LLM Output Diagnosis: Diagnosis: Lyme Disease
#
# * Probability: High
# * Urgency: High
# * Rationale: The patient has a history of an “insect bite” followed by chills, sweats, myalgia, back pain, headache, and fatigue, all consistent with Lyme disease
# Is the diagnosis correct? Yes
#
# Case 15:
# Correct Diagnosis: Metformin side effects
# LLM Output Diagnosis: Diagnosis:
#
# * Severe Acute Kidney Injury (AKI)
#
# Probability:
# * High
#
# Urgency: Critical
#
# Rationale:
# * The patient presents with significant worsening of her baseline creatinine levels from 1
# Is the diagnosis correct? No
#
# Case 16:
# Correct Diagnosis: AIS
# LLM Output Diagnosis: Diagnosis:
#
# * Ischemic Stroke:
#
# Probability: High
# Rationale:
# - MRI brain diffusion weighted images showed acute ischemic infarcts in bilateral cerebellar hemispheres, superior vermis, and PCA distribution
# - CT angiogram of head and neck revealed focal loss of gray-white differentiation involving the left temporal, occipital lobe in a left PCA distribution, and a region in the left cerebellar hemisphere with no flow-limiting stenosis of the major arteries of the neck
# - This evidence strongly suggests occlusion of the left posterior cerebral artery (PCA) and cerebellar branches leading to ischemic stroke
#
# Suitable Treatments:
# - Aspirin, Plavix, and high-intensity statin as prescribed
# - Close monitoring for improvement or deterioration of neurological symptoms
# - Referral to cardiology for PFO closure after further workup
#
# Urgency: Moderate to High
# Rationale: The patient had slurred speech, lethargy, visual hallucinations, and inability to get up from the floor; the neurological examination was significant for lethargy and decreased reflexes, and initial laboratory work-up was unremarkable
# Is the diagnosis correct? No
#
# Case 17:
# Correct Diagnosis: Galcanezumab-induced sexual dysfunction
# LLM Output Diagnosis: Diagnosis:
#
# * Migraine
#
# Probability: High
# * Probability can’t be calculated with the provided information
#
# Urgency: High
# *  This is a case of chronic migraine which is a debilitating condition that affects daily life
#
# Rationale:
# * The patient has had a history of chronic migraine without aura and migraine with aura
# Is the diagnosis correct? No
#
# Case 18:
# Correct Diagnosis: infective pharyngitis
# LLM Output Diagnosis: Diagnosis: Viral Pharyngitis
#
# * Probability: High
# * Urgency: Moderate
# * Rationale: The history of fever, pharyngeal pain, and throat pain for three days, coupled with the physical examination findings of a swollen and red pharynx without throat plaques, strongly suggests viral pharyngitis
# Is the diagnosis correct? Yes
#
# Case 19:
# Correct Diagnosis: sexual disorder secondary to therapy
# LLM Output Diagnosis:
# Is the diagnosis correct? No
#
# Case 20:
# Correct Diagnosis: bacterial meningitis
# LLM Output Diagnosis: Diagnosis: Meningitis
#
# * Probability: High
# * Urgency: Very High (Immediate medical intervention needed)
# * Rationale: The patient presents with fever, chills, worsening headache, neck pain, and back pain
# Is the diagnosis correct? Yes
#
# Accuracy of the diagnoses: 35.00%
